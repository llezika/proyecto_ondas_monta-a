# %%
import numpy as np
import matplotlib.pyplot as plt
import os
F_mensual=[]
H_fm_total=[]

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)

#COORDENADAS
dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-01-01_00.npz')
lat=dat['lat_popo']
lon=dat['lon_popo']
for i in range(1,32):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-01-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)
plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Enero',fontsize=30)

F_m_01=[]     
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_01.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_01')
F_mensual.append(max(F_m_01))

# %%
frec_hr_01=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_01.append(mask2.compressed().size)
frec_hr_01_s=sorted(frec_hr_01)
H_fm_total.append(frec_hr_01.index(frec_hr_01_s[-1]))
H_fm_total.append(frec_hr_01.index(frec_hr_01_s[-2]))
H_fm_total.append(frec_hr_01.index(frec_hr_01_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,29):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-02-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Febrero',fontsize=30)

F_m_02=[]      
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_02.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_02')
F_mensual.append(max(F_m_02))

# %%
frec_hr_02=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_02.append(mask2.compressed().size)
frec_hr_02_s=sorted(frec_hr_02)
H_fm_total.append(frec_hr_02.index(frec_hr_02_s[-1]))
H_fm_total.append(frec_hr_02.index(frec_hr_02_s[-2]))
H_fm_total.append(frec_hr_02.index(frec_hr_02_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):   
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-03-%02d_00.npz'%i)   
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Marzo',fontsize=30)

F_m_03=[]   
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_03.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_03')
F_mensual.append(max(F_m_03))

# %%
frec_hr_03=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_03.append(mask2.compressed().size)
frec_hr_03_s=sorted(frec_hr_03)
H_fm_total.append(frec_hr_03.index(frec_hr_03_s[-1]))
H_fm_total.append(frec_hr_03.index(frec_hr_03_s[-2]))
H_fm_total.append(frec_hr_03.index(frec_hr_03_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,31):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-04-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Abril',fontsize=30)

F_m_04=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_04.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_04')
F_mensual.append(max(F_m_04))

# %%
frec_hr_04=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_04.append(mask2.compressed().size)
frec_hr_04_s=sorted(frec_hr_04)
H_fm_total.append(frec_hr_04.index(frec_hr_04_s[-1]))
H_fm_total.append(frec_hr_04.index(frec_hr_04_s[-2]))
H_fm_total.append(frec_hr_04.index(frec_hr_04_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):
    if i==12:
        continue
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-05-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Mayo',fontsize=30)
F_m_05=[]       
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_05.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_05')
F_mensual.append(max(F_m_05))

# %%
frec_hr_05=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_05.append(mask2.compressed().size)
frec_hr_05_s=sorted(frec_hr_05)
H_fm_total.append(frec_hr_05.index(frec_hr_05_s[-1]))
H_fm_total.append(frec_hr_05.index(frec_hr_05_s[-2]))
H_fm_total.append(frec_hr_05.index(frec_hr_05_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,31):
    
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-06-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Junio',fontsize=30)
F_m_06=[]     
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_06.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_06')
F_mensual.append(max(F_m_06))

# %%
frec_hr_06=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_06.append(mask2.compressed().size)
frec_hr_06_s=sorted(frec_hr_06)
H_fm_total.append(frec_hr_06.index(frec_hr_06_s[-1]))
H_fm_total.append(frec_hr_06.index(frec_hr_06_s[-2]))
H_fm_total.append(frec_hr_06.index(frec_hr_06_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):
    
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-07-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Julio',fontsize=30)
F_m_07=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_07.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_07')
F_mensual.append(max(F_m_07))

# %%
frec_hr_07=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_07.append(mask2.compressed().size)
frec_hr_07_s=sorted(frec_hr_07)
H_fm_total.append(frec_hr_07.index(frec_hr_07_s[-1]))
H_fm_total.append(frec_hr_07.index(frec_hr_07_s[-2]))
H_fm_total.append(frec_hr_07.index(frec_hr_07_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-08-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Agosto',fontsize=30)
F_m_08=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_08.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_08')
F_mensual.append(max(F_m_08))

# %%
frec_hr_08=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_08.append(mask2.compressed().size)
frec_hr_08_s=sorted(frec_hr_08)
H_fm_total.append(frec_hr_08.index(frec_hr_08_s[-1]))
H_fm_total.append(frec_hr_08.index(frec_hr_08_s[-2]))
H_fm_total.append(frec_hr_08.index(frec_hr_08_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,31):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-09-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Septiembre',fontsize=30)
F_m_09=[] 
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_09.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))

#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_09')
F_mensual.append(max(F_m_09))

# %%
frec_hr_09=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_09.append(mask2.compressed().size)
frec_hr_09_s=sorted(frec_hr_09)
H_fm_total.append(frec_hr_09.index(frec_hr_09_s[-1]))
H_fm_total.append(frec_hr_09.index(frec_hr_09_s[-2]))
H_fm_total.append(frec_hr_09.index(frec_hr_09_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-10-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Octubre',fontsize=30)
F_m_10=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_10.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_10')
F_mensual.append(max(F_m_10))

# %%
frec_hr_10=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_10.append(mask2.compressed().size)
frec_hr_10_s=sorted(frec_hr_10)
H_fm_total.append(frec_hr_10.index(frec_hr_10_s[-1]))
H_fm_total.append(frec_hr_10.index(frec_hr_10_s[-2]))
H_fm_total.append(frec_hr_10.index(frec_hr_10_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,31):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-11-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Noviembre',fontsize=30)
F_m_11=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_11.append(all_hrs1.compressed().size)
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))
#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_11')
F_mensual.append(max(F_m_11))

# %%
frec_hr_11=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_11.append(mask2.compressed().size)
frec_hr_11_s=sorted(frec_hr_11)
H_fm_total.append(frec_hr_11.index(frec_hr_11_s[-1]))
H_fm_total.append(frec_hr_11.index(frec_hr_11_s[-2]))
H_fm_total.append(frec_hr_11.index(frec_hr_11_s[-3]))

# %%
all_hrs = np.empty(0, dtype=int)
all_pts = np.empty(0, dtype=int)
#COORDENADAS
for i in range(1,32):
    dat=np.load('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\Popo\\datos_2022-12-%02d_00.npz'%i)
    hrs=dat['hrs_16']
    pts=dat['pts16']
    all_hrs = np.append(all_hrs,hrs)
    all_pts = np.append(all_pts,pts)

plt.rcParams['axes.grid'] = True
fig,ax = plt.subplots(4,2, figsize=(20,20))
fig.suptitle('Diciembre',fontsize=30)
F_m_12=[]
for i in range(8):
    if i==3:
        continue
    mask1 = np.ma.masked_where(all_pts!=i, all_pts)
    all_hrs1 = np.ma.masked_where(np.ma.getmask(mask1),all_hrs)
    F_m_12.append(all_hrs1.compressed().size)
    
    if i < 2:
        ax[0,i].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[0,i].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[0,i].set_xlim(0,23)
        ax[0,i].set_ylim(0,30)
        ax[0,i].set_yticks(range(0, 31, 3))
    if i>=2 and i<4:
        ax[1,i-2].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[1,i-2].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[1,i-2].set_xlim(0,23)
        ax[1,i-2].set_ylim(0,30)
        ax[1,i-2].set_yticks(range(0, 31, 3))
    if i>=4 and i<6:
        ax[2,i-4].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[2,i-4].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[2,i-4].set_xlim(0,23)
        ax[2,i-4].set_ylim(0,30)
        ax[2,i-4].set_yticks(range(0, 31, 3))
    if i>=6 and i<8:
        ax[3,i-6].hist(all_hrs1.compressed(), bins=np.arange(25),rwidth=0.7,color='green')
        ax[3,i-6].set_title('Frecuencias en la coord(%f,%f)'%(lon[i],lat[i]))
        ax[3,i-6].set_xlim(0,23)
        ax[3,i-6].set_ylim(0,30)
        ax[3,i-6].set_yticks(range(0, 31, 3))

#plt.savefig('C:\\Users\\jesic\\Desktop\\Jesica\\Proyecto Terminal\\Salidas servidor\\Salidas servidor\\frec_popo\\Frec_12')
F_mensual.append(max(F_m_12))

# %%
frec_hr_12=[]
for t in range(24):
    mask2 = np.ma.masked_where(all_hrs!=t, all_hrs)
    #print(mask2)
    frec_hr_12.append(mask2.compressed().size)
frec_hr_12_s=sorted(frec_hr_12)
H_fm_total.append(frec_hr_12.index(frec_hr_12_s[-1]))
H_fm_total.append(frec_hr_12.index(frec_hr_12_s[-2]))
H_fm_total.append(frec_hr_12.index(frec_hr_12_s[-3]))

# %%
meses = ['enero','febrero','marzo','abril','mayo','junio','julio','agosto','septiembre','octubre','noviembre','diciembre']
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(1,1, figsize=(20,20))
ax.set_title('Frecuencias Mensuales Popocatepetl')
plt.bar(range(1,13),F_mensual,color='green',tick_label=meses)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
plt.savefig('Frec_mensual_popo')

# %%
fig,ax = plt.subplots(1,1, figsize=(20,20))
ax.set_title('Frecuencias por hora para el mes de Diciembre en el Popocatepetl')
plt.bar(range(24),frec_hr_12,color='green')
ax.set_xlabel('horas')
plt.savefig('Frec_horaria_popo')

# %%
fig,ax= plt.subplots(1,1, figsize=(20,15))
ax.hist(H_fm_total, bins=np.arange(25),rwidth=0.7,color='green')
ax.set_title('Frecuencia anual por hora')
ax.set_xlim(0,23)
plt.savefig('frec_anual_hora_popo.png')
#ax.set_yticks(range(0, 31, 3))
